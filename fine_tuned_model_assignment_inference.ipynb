# %%
from google.colab import files
files.upload()

# %%
files.upload()
# Out:
#      <input type="file" id="files-3c80f378-88c4-4be5-92bc-1d703f742e83" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c80f378-88c4-4be5-92bc-1d703f742e83">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Installing requirements for running script

# %%
# !python -m pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 30.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 93.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 52.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.0
#     Uninstalling tokenizers-0.15.0:
#       Successfully uninstalled tokenizers-0.15.0
#   Attempting uninstall: transformers
# ...

# %% [markdown]
# ## Running script using HuggingFace token and assigning name to the new model to be pushed to hub

# %%
# !python fine_tuning_assignment_final.py --hf-token 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  --hf-repo llama-2-inf-test-1
# Out:
# 2023-12-22 20:17:01.161771: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-22 20:17:01.161834: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-22 20:17:01.163972: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-22 20:17:02.739927: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# ...

# %% [markdown]
# ## Importing model from HuggingFace using API for Inference and Testing on prompts

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

device_map = {"":0}

model = AutoModelForCausalLM.from_pretrained("retr0sushi04/llama-2-inf-test-1", load_in_4bit=True, torch_dtype=torch.float16, device_map=device_map)
tokenizer = AutoTokenizer.from_pretrained("retr0sushi04/llama-2-inf-test-1")


task = "Create a design page with HTML programming language"

pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=200)
result = pipe(f"<s> [INST] {task} [/INST]")
print(result[0]['generated_text'])
# Out:
# config.json:   0%|          | 0.00/630 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/183 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# ...

# %%
task = "Create a bold about page that includes animations in HTML programming language"

pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=200)
result = pipe(f"<s> [INST] {task} [/INST]")
print(result[0]['generated_text'])
# Out:
# <s> [INST] Create a bold about page that includes animations in HTML programming language [/INST] <div id="wrapper">
#  persones,</div><div id="page-content"> <div id="page-header"> <div id="page-logo"> <a href="/en/"><img src="/core/default/assets/web/logo.svg" alt="Revolution PABLO" /></a> </div> <div id="page-title"> <h1>Revolution PABLO</h1> <ul> <li><a href="/en/">English</a></li> <li><a href="/es/">Español</a></li> </ul> </div> <div id="page-breadcrumb"> <ol> <li><a href="/en/">Home</a></li> <li>About</li> </ol> </div> <div

# %%
task = "Create a clean login page in HTML programming language"

pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=200)
result = pipe(f"<s> [INST] {task} [/INST]")

# %%
print(result[0]['generated_text'])
# Out:
# <s> [INST] Create a clean login page in HTML programming language [/INST] <div id="app"><div id="page-header"><div class="page-header-inner"><div class="container"><div class="page-header-logo"><a href="/"><img src="/images/logo. Википедии.com-48.png" alt="Wikipedia" class="logo"></a></div><div class="page-header-nav"><nav id="nav-main"><a href="/">Home</a><span class="current-language">-</span> <a href="/articles?language=fr">Fr</a><a href="/articles?language=es">Es</a><a href="/articles?language=pt">Pt</a><a href="/articles?language=de">De</a><a href="/articles?language=ja"> Ja</a><a href="/articles?language=zh"> Zh</
